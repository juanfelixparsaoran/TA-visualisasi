# %%
import pandas as pd

df = pd.read_csv('Mini Survey Structures (Responses).csv')

# %%
df
# Out:
#              Timestamp     What is your level of understanding on Python?  \
# 0   8/21/2021 11:51:47  Know what Python is, but don't know how to use it
# 1   8/21/2021 11:52:05  Know what Python is, but don't know how to use it
# 2   8/21/2021 11:52:05                      Have written a code in Python
# 3   8/21/2021 11:52:07  Know what Python is, but don't know how to use it
# 4   8/21/2021 11:52:10                      Have written a code in Python
# 5   8/21/2021 11:52:13  Know what Python is, but don't know how to use it
# 6   8/21/2021 11:52:14                      Have written a code in Python
# 7   8/21/2021 11:52:15                      Have written a code in Python
# 8   8/21/2021 11:52:19                      Have written a code in Python
# 9   8/21/2021 11:52:20  Know what Python is, but don't know how to use it
# 10  8/21/2021 11:52:23  Know what Python is, but don't know how to use it
# 11  8/21/2021 11:52:23                      Have written a code in Python
# ...

# %%
# Filter dataframe with several criterias (OR)
df[((df['How well do you understand the concept of List in Python?']<3) & 
           (df['How well do you understand the concept of Tuple in Python?']>3)) | ((df['How well do you understand the concept of List in Python?']>3) & 
           (df['How well do you understand the concept of Tuple in Python?']<3))]
# Out:
#              Timestamp     What is your level of understanding on Python?  \
# 6   8/21/2021 11:52:14                      Have written a code in Python
# 31  8/21/2021 11:53:18  Know what Python is, but don't know how to use it
#
#     How well do you understand the concept of Primitive Data Structures in Python (Integer, Float, Boolean, String)?  \
# 6                                                   3
# 31                                                  4
#
#     How well do you understand the concept of List in Python?  \
# 6                                                   2
# 31                                                  4
#
#     How well do you understand the concept of Array in Python?  \
# 6                                                   2
# 31                                                  4
#
#     How well do you understand the concept of Matrix in Python?  \
# 6                                                   2
# ...
